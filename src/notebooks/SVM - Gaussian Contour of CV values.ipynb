# %%
# %matplotlib nbagg

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

df = pd.read_csv('../../data/grid_gaussian_protein_search_scores_1450680293.out')
X = df.as_matrix()
df
# Out:
#           mean  svm_gaussian__C  pca__n_components  svm_gaussian__gamma
# 0     0.565217         0.001953                  6             0.001953
# 1     0.565217         0.001953                  6             0.003906
# 2     0.565217         0.001953                  6             0.007812
# 3     0.565217         0.001953                  6             0.015625
# 4     0.565217         0.001953                  6             0.031250
# 5     0.565217         0.001953                  6             0.062500
# 6     0.565217         0.001953                  6             0.125000
# 7     0.565217         0.001953                  6             0.250000
# 8     0.565217         0.001953                  6             0.500000
# 9     0.565217         0.001953                  6             1.000000
# 10    0.565217         0.001953                  6             2.000000
# 11    0.565217         0.001953                  6             4.000000
# 12    0.565217         0.001953                  6             8.000000
# 13    0.556522         0.001953                  6            16.000000
# 14    0.565217         0.001953                  6            32.000000
# 15    0.565217         0.001953                  6            64.000000
# 16    0.565217         0.001953                  6           128.000000
# 17    0.565217         0.001953                  6           256.000000
# 18    0.565217         0.001953                  6           512.000000
# 19    0.565217         0.003906                  6             0.001953
# 20    0.565217         0.003906                  6             0.003906
# 21    0.565217         0.003906                  6             0.007812
# 22    0.565217         0.003906                  6             0.015625
# 23    0.565217         0.003906                  6             0.031250
# 24    0.565217         0.003906                  6             0.062500
# 25    0.565217         0.003906                  6             0.125000
# 26    0.565217         0.003906                  6             0.250000
# 27    0.565217         0.003906                  6             0.500000
# 28    0.565217         0.003906                  6             1.000000
# 29    0.565217         0.003906                  6             2.000000
# ...        ...              ...                ...                  ...
# 2136  0.600000       256.000000                116             0.500000
# 2137  0.600000       256.000000                116             1.000000
# 2138  0.600000       256.000000                116             2.000000
# 2139  0.600000       256.000000                116             4.000000
# 2140  0.600000       256.000000                116             8.000000
# 2141  0.600000       256.000000                116            16.000000
# 2142  0.600000       256.000000                116            32.000000
# 2143  0.600000       256.000000                116            64.000000
# 2144  0.600000       256.000000                116           128.000000
# 2145  0.600000       256.000000                116           256.000000
# 2146  0.600000       256.000000                116           512.000000
# 2147  0.873913       512.000000                116             0.001953
# 2148  0.865217       512.000000                116             0.003906
# 2149  0.834783       512.000000                116             0.007812
# 2150  0.813043       512.000000                116             0.015625
# 2151  0.778261       512.000000                116             0.031250
# 2152  0.600000       512.000000                116             0.062500
# 2153  0.600000       512.000000                116             0.125000
# 2154  0.600000       512.000000                116             0.250000
# 2155  0.600000       512.000000                116             0.500000
# 2156  0.600000       512.000000                116             1.000000
# 2157  0.600000       512.000000                116             2.000000
# 2158  0.600000       512.000000                116             4.000000
# 2159  0.600000       512.000000                116             8.000000
# 2160  0.600000       512.000000                116            16.000000
# 2161  0.600000       512.000000                116            32.000000
# 2162  0.600000       512.000000                116            64.000000
# 2163  0.600000       512.000000                116           128.000000
# 2164  0.600000       512.000000                116           256.000000
# 2165  0.600000       512.000000                116           512.000000
#
# [2166 rows x 4 columns]

# %%
best_C = 32
best_n_c = 66
best_gamma = 0.00390625

import scipy.interpolate


fig1 = plt.figure()
ax1 = fig1.add_subplot(111)

tmp = X[X[:,2] == best_n_c]

x, y, z  = tmp[:,1], tmp[:,3], tmp[:,0]

xi, yi = np.linspace(x.min(), x.max(), 100), np.linspace(y.min(), y.max(), 100)
xi, yi = np.meshgrid(xi, yi)

rbf = scipy.interpolate.Rbf(x, y, z, function='linear')
zi = rbf(xi, yi)

plt.imshow(zi, vmin=z.min(), vmax=z.max(), origin='lower',
           extent=[x.min(), x.max(), y.min(), y.max()])
plt.scatter(x, y, c=z)
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
cset = ax.contour(X, Y, Z, cmap=cm.coolwarm)
ax.clabel(cset, fontsize=9, inline=1)

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print(X.shape, Y.shape, Z.shape)
# Out:
# (120, 120) (120, 120) (120, 120)

# %%
np.unique(df[df['pca__n_components'] == 20].as_matrix()[:,0])
# Out:
# array([ 0.99358974,  0.9957265 ,  0.99786325])
