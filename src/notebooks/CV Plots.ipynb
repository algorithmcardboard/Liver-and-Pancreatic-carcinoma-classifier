# %%
# %matplotlib nbagg

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../../data/grid_linear_cancer_search_scores_1450680262.out')
df
# Out:
#          mean  svm_linear__C  pca__n_components
# 0    0.959402       0.001953                  4
# 1    0.970085       0.003906                  4
# 2    0.982906       0.007812                  4
# 3    0.987179       0.015625                  4
# 4    0.989316       0.031250                  4
# 5    0.989316       0.062500                  4
# 6    0.991453       0.125000                  4
# 7    0.991453       0.250000                  4
# 8    0.989316       0.500000                  4
# 9    0.987179       1.000000                  4
# 10   0.987179       2.000000                  4
# 11   0.987179       4.000000                  4
# 12   0.989316       8.000000                  4
# 13   0.989316      16.000000                  4
# 14   0.989316      32.000000                  4
# 15   0.989316      64.000000                  4
# 16   0.989316     128.000000                  4
# 17   0.989316     256.000000                  4
# 18   0.989316     512.000000                  4
# 19   0.993590       0.001953                 20
# 20   0.993590       0.003906                 20
# 21   0.993590       0.007812                 20
# 22   0.995726       0.015625                 20
# 23   0.997863       0.031250                 20
# 24   0.997863       0.062500                 20
# 25   0.997863       0.125000                 20
# 26   0.997863       0.250000                 20
# 27   0.997863       0.500000                 20
# 28   0.997863       1.000000                 20
# 29   0.997863       2.000000                 20
# ..        ...            ...                ...
# 84   0.997863       0.500000                361
# 85   0.997863       1.000000                361
# 86   0.997863       2.000000                361
# 87   0.997863       4.000000                361
# 88   0.997863       8.000000                361
# 89   0.997863      16.000000                361
# 90   0.997863      32.000000                361
# 91   0.997863      64.000000                361
# 92   0.997863     128.000000                361
# 93   0.997863     256.000000                361
# 94   0.997863     512.000000                361
# 95   0.504274       0.001953                513
# 96   0.504274       0.003906                513
# 97   0.504274       0.007812                513
# 98   0.504274       0.015625                513
# 99   0.504274       0.031250                513
# 100  0.504274       0.062500                513
# 101  0.504274       0.125000                513
# 102  0.504274       0.250000                513
# 103  0.504274       0.500000                513
# 104  0.504274       1.000000                513
# 105  0.504274       2.000000                513
# 106  0.504274       4.000000                513
# 107  0.504274       8.000000                513
# 108  0.504274      16.000000                513
# 109  0.504274      32.000000                513
# 110  0.504274      64.000000                513
# 111  0.504274     128.000000                513
# 112  0.504274     256.000000                513
# 113  0.504274     512.000000                513
#
# [114 rows x 3 columns]

# %%
X = df.as_matrix()

# %%
X.shape
# Out:
# (114, 3)

# %%
np.unique(X[:,2])
# Out:
# array([   4.,   20.,   92.,  255.,  361.,  513.])

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
for c in [0.03125]:
    tmp = X[X[:,1] == c]
    print(tmp)
    plt.plot(tmp[:,2], tmp[:,0])
# Out:
# <img src="data:image/png;base64,...">
# [[  9.89316239e-01   3.12500000e-02   4.00000000e+00]
#  [  9.97863248e-01   3.12500000e-02   2.00000000e+01]
#  [  9.95726496e-01   3.12500000e-02   9.20000000e+01]
#  [  9.97863248e-01   3.12500000e-02   2.55000000e+02]
#  [  9.97863248e-01   3.12500000e-02   3.61000000e+02]
#  [  5.04273504e-01   3.12500000e-02   5.13000000e+02]]

# %%
X_axes = ['L_svm', 'G_svm', 'AdaBoost', 'Logistic Regression', 'G. Naive Bayes']
heights = np.array([85.71, 93.51, 90.90, 92.21, 81.82])
colors = ['#C95834','#728CAC','#AA8D66','#319E98','#AF69AF']

ind = np.arange(len(X_axes))

fig2 = plt.figure(figsize=(12,5))
ax2 = fig2.add_subplot(111)
ax2.bar(ind+0.125, heights-80, width=0.25, color=colors, bottom=80)
plt.xticks(ind+0.25, X_axes, rotation=0)
plt.xlabel("Classifiers")
plt.ylabel("Accuracy")
plt.title("Performance of various classifiers for Protein expression data")
# Out:
# <img src="data:image/png;base64,...">

# %%
#X_axes = ['L_svm', 'G_svm', 'AdaBoost', 'Logistic Regression', 'G. Naive Bayes']
heights2 = np.array([98.09, 95.83, 94.23, 97.21, 96.81])

fig3 = plt.figure(figsize=(12,5))
ax3 = fig3.add_subplot(111)
ax3.bar(ind+0.125, heights2-80, width=0.25, color=colors, bottom=80)
plt.xticks(ind+0.25, X_axes, rotation=0)
plt.xlabel("Classifiers")
plt.ylabel("Accuracy")
plt.title("Performance of various classifiers for DNA Methylation data")
# Out:
# <img src="data:image/png;base64,...">
