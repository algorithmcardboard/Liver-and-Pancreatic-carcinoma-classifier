# %%
# %matplotlib nbagg

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

df = pd.read_csv('../../data/grid_linear_cancer_search_scores_1450680262.out')
X = df.as_matrix()

# %%
fig = plt.figure()
ax = Axes3D(fig)
surf = ax.contour(X[:,0], X[:,1], X[:,2])
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-6c8e27df04af> in <module>()
#       1 fig = plt.figure()
#       2 ax = Axes3D(fig)
# ----> 3 surf = ax.contour(X[:,0], X[:,1], X[:,2])
#       4 plt.show()
#
# /home/anirudhan/workspace/Pancreatic-carcinoma-classifier/src/.venv/lib/python3.4/site-packages/mpl_toolkits/mplot3d/axes3d.py in contour(self, X, Y, Z, *args, **kwargs)
#    2027
#    2028         jX, jY, jZ = art3d.rotate_axes(X, Y, Z, zdir)
# -> 2029         cset = Axes.contour(self, jX, jY, jZ, *args, **kwargs)
#    2030         self.add_contour_set(cset, extend3d, stride, zdir, offset)
#    2031
#
# /home/anirudhan/workspace/Pancreatic-carcinoma-classifier/src/.venv/lib/python3.4/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
#    1810                                   RuntimeWarning, stacklevel=2)
# -> 1811             return func(ax, *args, **kwargs)
#    1812         pre_doc = inner.__doc__
#    1813         if pre_doc is None:
#
# /home/anirudhan/workspace/Pancreatic-carcinoma-classifier/src/.venv/lib/python3.4/site-packages/matplotlib/axes/_axes.py in contour(self, *args, **kwargs)
#    5638             self.cla()
#    5639         kwargs['filled'] = False
# -> 5640         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5641     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    5642
#
# /home/anirudhan/workspace/Pancreatic-carcinoma-classifier/src/.venv/lib/python3.4/site-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#    1426         are described in QuadContourSet.contour_doc.
#    1427         """
# -> 1428         ContourSet.__init__(self, ax, *args, **kwargs)
#    1429
#    1430     def _process_args(self, *args, **kwargs):
#
# /home/anirudhan/workspace/Pancreatic-carcinoma-classifier/src/.venv/lib/python3.4/site-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#     871         self._transform = kwargs.get('transform', None)
#     872
# --> 873         self._process_args(*args, **kwargs)
#     874         self._process_levels()
#     875
#
# /home/anirudhan/workspace/Pancreatic-carcinoma-classifier/src/.venv/lib/python3.4/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1443                 contour_generator = args[0]._contour_generator
#    1444         else:
# -> 1445             x, y, z = self._contour_args(args, kwargs)
#    1446
#    1447             _mask = ma.getmask(z)
#
# /home/anirudhan/workspace/Pancreatic-carcinoma-classifier/src/.venv/lib/python3.4/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1530             args = args[1:]
#    1531         elif Nargs <= 4:
# -> 1532             x, y, z = self._check_xyz(args[:3], kwargs)
#    1533             args = args[3:]
#    1534         else:
#
# /home/anirudhan/workspace/Pancreatic-carcinoma-classifier/src/.venv/lib/python3.4/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1564
#    1565         if z.ndim != 2:
# -> 1566             raise TypeError("Input z must be a 2D array.")
#    1567         else:
#    1568             Ny, Nx = z.shape
#
# TypeError: Input z must be a 2D array.

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
cset = ax.contour(X, Y, Z, cmap=cm.coolwarm)
ax.clabel(cset, fontsize=9, inline=1)

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print(X.shape, Y.shape, Z.shape)
# Out:
# (120, 120) (120, 120) (120, 120)

# %%
df[df['pca__n_components'] == 20]
# Out:
#         mean  svm_linear__C  pca__n_components
# 19  0.993590       0.001953                 20
# 20  0.993590       0.003906                 20
# 21  0.993590       0.007812                 20
# 22  0.995726       0.015625                 20
# 23  0.997863       0.031250                 20
# 24  0.997863       0.062500                 20
# 25  0.997863       0.125000                 20
# 26  0.997863       0.250000                 20
# 27  0.997863       0.500000                 20
# 28  0.997863       1.000000                 20
# 29  0.997863       2.000000                 20
# 30  0.995726       4.000000                 20
# 31  0.995726       8.000000                 20
# 32  0.995726      16.000000                 20
# 33  0.995726      32.000000                 20
# 34  0.995726      64.000000                 20
# 35  0.995726     128.000000                 20
# 36  0.995726     256.000000                 20
# 37  0.995726     512.000000                 20
